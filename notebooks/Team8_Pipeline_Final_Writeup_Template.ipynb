# %% [markdown]
# # Team 8 Notebook 3: Pipeline + Final Write-Up
#
# This notebook is for **Developing the pipeline for our project to complete the development along with a Write-Up**.
#
# ## Responsibilities
# - Write the project pipeline from start to finish
# - Plan a simple pipeline diagram
# - Start the Methodology section
# - Merge everyone’s writing into one clean paper
# - Fix flow, grammar, and APA formatting
# - Add the LLM acknowledgement
# - Prepare the final PDF handoff and submission checklist

# %%
import pandas as pd
from textwrap import dedent

# %% [markdown]
# ## 1. End-to-end project pipeline

# %%
pipeline_steps = [
    "Receive or collect antiviral molecular records from public sources.",
    "Load the raw dataset into the project workflow.",
    "Validate structures, standardize columns, and remove unusable records.",
    "Perform EDA to understand distributions, missingness, duplicates, and key patterns.",
    "Prepare the data for modeling through cleaning, transformation, and feature engineering.",
    "Train or test candidate models appropriate for the project objective.",
    "Evaluate outputs using validity, relevance, and project-specific scoring criteria.",
    "Surface findings and candidate outputs in the final artifact or report."
]

for i, step in enumerate(pipeline_steps, 1):
    print(f"{i}. {step}")
# Out:
# 1. Receive or collect antiviral molecular records from public sources.
# 2. Load the raw dataset into the project workflow.
# 3. Validate structures, standardize columns, and remove unusable records.
# 4. Perform EDA to understand distributions, missingness, duplicates, and key patterns.
# 5. Prepare the data for modeling through cleaning, transformation, and feature engineering.
# 6. Train or test candidate models appropriate for the project objective.
# 7. Evaluate outputs using validity, relevance, and project-specific scoring criteria.
# 8. Surface findings and candidate outputs in the final artifact or report.

# %% [markdown]
# ## 2. Pipeline diagram planning

# %%
diagram_blocks = pd.DataFrame({
    "block_order": [1, 2, 3, 4, 5, 6, 7, 8],
    "block_name": [
        "Raw Data",
        "Validation",
        "EDA",
        "Cleaning",
        "Feature Engineering",
        "Modeling",
        "Evaluation",
        "Final Artifact"
    ],
    "notes": ["", "", "", "", "", "", "", ""]
})

diagram_blocks
# Out:
#    block_order           block_name notes
# 0            1             Raw Data
# 1            2           Validation
# 2            3                  EDA
# 3            4             Cleaning
# 4            5  Feature Engineering
# 5            6             Modeling
# 6            7           Evaluation
# 7            8       Final Artifact

# %% [markdown]
# ## 3. Methodology starter paragraph

# %%
methodology_paragraph = dedent("""
This project followed an end-to-end analytical pipeline that moved from raw molecular records to modeling-ready data and, ultimately, to interpretable outputs suitable for inclusion in a user-facing artifact. The workflow began with data acquisition and validation, followed by exploratory analysis to understand dataset quality and feature behavior. After cleaning and feature engineering, the prepared data were organized for downstream modeling and evaluation. This structure was appropriate because the project required both careful handling of chemistry-based data and a reproducible pathway from raw records to actionable project outputs.
""").strip()

print(methodology_paragraph)
# Out:
# This project followed an end-to-end analytical pipeline that moved from raw molecular records to modeling-ready data and, ultimately, to interpretable outputs suitable for inclusion in a user-facing artifact. The workflow began with data acquisition and validation, followed by exploratory analysis to understand dataset quality and feature behavior. After cleaning and feature engineering, the prepared data were organized for downstream modeling and evaluation. This structure was appropriate because the project required both careful handling of chemistry-based data and a reproducible pathway from raw records to actionable project outputs.

# %% [markdown]
# ## 4. Merge plan for the paper

# %%
merge_plan = [
    "Insert Teammate 1 content into the Data Understanding section.",
    "Insert Teammate 2 content into the Methodology data preparation section.",
    "Revise transitions so the paper reads like one voice.",
    "Replace bullet-style notes with full paragraphs.",
    "Check that each figure and table is referenced in the text."
]

for item in merge_plan:
    print("-", item)
# Out:
# - Insert Teammate 1 content into the Data Understanding section.
# - Insert Teammate 2 content into the Methodology data preparation section.
# - Revise transitions so the paper reads like one voice.
# - Replace bullet-style notes with full paragraphs.
# - Check that each figure and table is referenced in the text.

# %% [markdown]
# ## 5. APA and writing quality checklist

# %%
apa_checklist = {
    "In-text citations added where needed": False,
    "Reference list alphabetized": False,
    "APA 7 format checked": False,
    "Grammar and spelling reviewed": False,
    "New milestone text marked in blue in the article": False,
    "No raw code screenshots included": False
}

apa_checklist
# Out:
# {'In-text citations added where needed': False,
#  'Reference list alphabetized': False,
#  'APA 7 format checked': False,
#  'Grammar and spelling reviewed': False,
#  'New milestone text marked in blue in the article': False,
#  'No raw code screenshots included': False}

# %% [markdown]
# ## 6. LLM acknowledgement draft

# %%
llm_acknowledgement = dedent("""
The authors used ChatGPT to support notebook templating, workflow planning, and early drafting support for selected sections of the capstone article. All AI-assisted outputs were reviewed, revised, and validated by the authors, who take full responsibility for the final content of the submission.
""").strip()

print(llm_acknowledgement)
# Out:
# The authors used ChatGPT to support notebook templating, workflow planning, and early drafting support for selected sections of the capstone article. All AI-assisted outputs were reviewed, revised, and validated by the authors, who take full responsibility for the final content of the submission.

# %% [markdown]
# ## 7. Final PDF handoff checklist

# %%
final_submission_checklist = [
    "All Milestone 4.1 sections are complete.",
    "Figures have titles, labels, and captions.",
    "Tables are readable and referenced in the paper.",
    "Acknowledgements section includes LLM usage if applicable.",
    "The article is exported to PDF.",
    "One teammate is assigned to submit the PDF."
]

for item in final_submission_checklist:
    print("-", item)
# Out:
# - All Milestone 4.1 sections are complete.
# - Figures have titles, labels, and captions.
# - Tables are readable and referenced in the paper.
# - Acknowledgements section includes LLM usage if applicable.
# - The article is exported to PDF.
# - One teammate is assigned to submit the PDF.

# %% [markdown]
# ## 8. Final write-up notes

# %%
final_notes = [
    "Transition from Background/Literature Review into Data Understanding.",
    "Transition from Data Understanding into Methodology.",
    "One sentence introducing each figure and table.",
    "One final pass for consistent tone and word choice."
]

for note in final_notes:
    print("-", note)
# Out:
# - Transition from Background/Literature Review into Data Understanding.
# - Transition from Data Understanding into Methodology.
# - One sentence introducing each figure and table.
# - One final pass for consistent tone and word choice.
